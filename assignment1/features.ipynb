# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from cs231n.data_utils import load_CIFAR10



# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 0.5e-8, 1e-8, 0.5e-7, 1e-7]
regularization_strengths = [5e4, 1e5, 5e5, 1e6, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)***** 
for i in learning_rates:
    for j in regularization_strengths:
        svm = LinearSVM()
        svm.train(X_train_feats, y_train, learning_rate = i, reg = j, num_iters = 1000, verbose = False)
        train_accuracy = np.mean(svm.predict(X_train_feats) == y_train)
        val_accuracy = np.mean(svm.predict(X_val_feats) == y_val)
        results[(i,j)] = (train_accuracy, val_accuracy)
        
        if val_accuracy > best_val:
            best_val = val_accuracy
            best_svm = svm
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.112143 val accuracy: 0.108000
# lr 1.000000e-09 reg 1.000000e+05 train accuracy: 0.130490 val accuracy: 0.127000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.095245 val accuracy: 0.082000
# lr 1.000000e-09 reg 1.000000e+06 train accuracy: 0.094041 val accuracy: 0.094000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.309633 val accuracy: 0.316000
# lr 5.000000e-09 reg 5.000000e+04 train accuracy: 0.126122 val accuracy: 0.144000
# lr 5.000000e-09 reg 1.000000e+05 train accuracy: 0.106939 val accuracy: 0.113000
# lr 5.000000e-09 reg 5.000000e+05 train accuracy: 0.110347 val accuracy: 0.103000
# lr 5.000000e-09 reg 1.000000e+06 train accuracy: 0.415388 val accuracy: 0.422000
# lr 5.000000e-09 reg 5.000000e+06 train accuracy: 0.416449 val accuracy: 0.423000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.103673 val accuracy: 0.117000
# lr 1.000000e-08 reg 1.000000e+05 train accuracy: 0.092490 val accuracy: 0.085000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.411367 val accuracy: 0.405000
# lr 1.000000e-08 reg 1.000000e+06 train accuracy: 0.415980 val accuracy: 0.413000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.408796 val accuracy: 0.403000
# lr 5.000000e-08 reg 5.000000e+04 train accuracy: 0.264347 val accuracy: 0.273000
# lr 5.000000e-08 reg 1.000000e+05 train accuracy: 0.416612 val accuracy: 0.418000
# lr 5.000000e-08 reg 5.000000e+05 train accuracy: 0.407469 val accuracy: 0.407000
# lr 5.000000e-08 reg 1.000000e+06 train accuracy: 0.405816 val accuracy: 0.396000
# lr 5.000000e-08 reg 5.000000e+06 train accuracy: 0.376245 val accuracy: 0.370000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.418102 val accuracy: 0.422000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.414469 val accuracy: 0.420000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.403939 val accuracy: 0.411000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.395347 val accuracy: 0.402000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.320082 val accuracy: 0.316000
# best validation accuracy achieved during cross-validation: 0.423000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.422

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

best_val = -1
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
hidden_layer_size = [100,150,200,300,400,500]
learningrate = [1e-1,2e-1,3e-1,4e-1,5e-1]
regular = [1e-7,5e-7,1e-6,5e-6,1e-5,5e-5,1e-4,5e-4]
for h in hidden_layer_size:
    for lr in learningrate:
        for reg in regular:
            net = TwoLayerNet(X_train_feats.shape[1], h, 10)
            net.train(X_train_feats, y_train, X_val_feats, y_val, num_iters = 1000, batch_size = 200, learning_rate = lr, learning_rate_decay = 0.95, reg = reg, verbose = False)
            training_accuracy = np.mean(net.predict(X_train_feats) == y_train)
            val_accuracy = np.mean(net.predict(X_val_feats) == y_val)
            
            if val_accuracy > best_val:
                best_val = val_accuracy
                best_net = net
            
            print('lr %e reg %e hidden units %d training accuracy: %f validation accuracy: %f' % (lr, reg, h, training_accuracy, val_accuracy))
            print('best validation accuracy: %f' % best_val)
pass

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# lr 1.000000e-01 reg 1.000000e-07 hidden units 100 training accuracy: 0.517551 validation accuracy: 0.504000
# best validation accuracy: 0.504000
# lr 1.000000e-01 reg 5.000000e-07 hidden units 100 training accuracy: 0.516204 validation accuracy: 0.509000
# best validation accuracy: 0.509000
# lr 1.000000e-01 reg 1.000000e-06 hidden units 100 training accuracy: 0.518429 validation accuracy: 0.508000
# best validation accuracy: 0.509000
# lr 1.000000e-01 reg 5.000000e-06 hidden units 100 training accuracy: 0.519837 validation accuracy: 0.505000
# best validation accuracy: 0.509000
# lr 1.000000e-01 reg 1.000000e-05 hidden units 100 training accuracy: 0.517592 validation accuracy: 0.514000
# best validation accuracy: 0.514000
# lr 1.000000e-01 reg 5.000000e-05 hidden units 100 training accuracy: 0.519041 validation accuracy: 0.511000
# best validation accuracy: 0.514000
# lr 1.000000e-01 reg 1.000000e-04 hidden units 100 training accuracy: 0.519265 validation accuracy: 0.512000
# best validation accuracy: 0.514000
# lr 1.000000e-01 reg 5.000000e-04 hidden units 100 training accuracy: 0.514592 validation accuracy: 0.508000
# best validation accuracy: 0.514000
# lr 2.000000e-01 reg 1.000000e-07 hidden units 100 training accuracy: 0.553592 validation accuracy: 0.523000
# best validation accuracy: 0.523000
# lr 2.000000e-01 reg 5.000000e-07 hidden units 100 training accuracy: 0.548796 validation accuracy: 0.513000
# best validation accuracy: 0.523000
# lr 2.000000e-01 reg 1.000000e-06 hidden units 100 training accuracy: 0.555306 validation accuracy: 0.541000
# best validation accuracy: 0.541000
# lr 2.000000e-01 reg 5.000000e-06 hidden units 100 training accuracy: 0.555857 validation accuracy: 0.529000
# best validation accuracy: 0.541000
# lr 2.000000e-01 reg 1.000000e-05 hidden units 100 training accuracy: 0.553102 validation accuracy: 0.534000
# best validation accuracy: 0.541000
# lr 2.000000e-01 reg 5.000000e-05 hidden units 100 training accuracy: 0.554612 validation accuracy: 0.520000
# best validation accuracy: 0.541000
# lr 2.000000e-01 reg 1.000000e-04 hidden units 100 training accuracy: 0.550959 validation accuracy: 0.531000
# best validation accuracy: 0.541000
# lr 2.000000e-01 reg 5.000000e-04 hidden units 100 training accuracy: 0.552327 validation accuracy: 0.541000
# best validation accuracy: 0.541000
# lr 3.000000e-01 reg 1.000000e-07 hidden units 100 training accuracy: 0.575204 validation accuracy: 0.550000
# best validation accuracy: 0.550000
# lr 3.000000e-01 reg 5.000000e-07 hidden units 100 training accuracy: 0.578082 validation accuracy: 0.550000
# best validation accuracy: 0.550000
# lr 3.000000e-01 reg 1.000000e-06 hidden units 100 training accuracy: 0.583633 validation accuracy: 0.543000
# best validation accuracy: 0.550000
# lr 3.000000e-01 reg 5.000000e-06 hidden units 100 training accuracy: 0.582245 validation accuracy: 0.547000
# best validation accuracy: 0.550000
# lr 3.000000e-01 reg 1.000000e-05 hidden units 100 training accuracy: 0.577694 validation accuracy: 0.541000
# best validation accuracy: 0.550000
# lr 3.000000e-01 reg 5.000000e-05 hidden units 100 training accuracy: 0.577082 validation accuracy: 0.556000
# best validation accuracy: 0.556000
# lr 3.000000e-01 reg 1.000000e-04 hidden units 100 training accuracy: 0.574898 validation accuracy: 0.534000
# best validation accuracy: 0.556000
# lr 3.000000e-01 reg 5.000000e-04 hidden units 100 training accuracy: 0.576918 validation accuracy: 0.551000
# best validation accuracy: 0.556000
# lr 4.000000e-01 reg 1.000000e-07 hidden units 100 training accuracy: 0.592082 validation accuracy: 0.556000
# best validation accuracy: 0.556000
# lr 4.000000e-01 reg 5.000000e-07 hidden units 100 training accuracy: 0.593143 validation accuracy: 0.556000
# best validation accuracy: 0.556000
# lr 4.000000e-01 reg 1.000000e-06 hidden units 100 training accuracy: 0.596408 validation accuracy: 0.556000
# best validation accuracy: 0.556000
# lr 4.000000e-01 reg 5.000000e-06 hidden units 100 training accuracy: 0.595653 validation accuracy: 0.549000
# best validation accuracy: 0.556000
# lr 4.000000e-01 reg 1.000000e-05 hidden units 100 training accuracy: 0.597735 validation accuracy: 0.553000
# best validation accuracy: 0.556000
# lr 4.000000e-01 reg 5.000000e-05 hidden units 100 training accuracy: 0.594204 validation accuracy: 0.566000
# best validation accuracy: 0.566000
# lr 4.000000e-01 reg 1.000000e-04 hidden units 100 training accuracy: 0.602388 validation accuracy: 0.571000
# best validation accuracy: 0.571000
# lr 4.000000e-01 reg 5.000000e-04 hidden units 100 training accuracy: 0.590082 validation accuracy: 0.556000
# best validation accuracy: 0.571000
# lr 5.000000e-01 reg 1.000000e-07 hidden units 100 training accuracy: 0.608694 validation accuracy: 0.567000
# best validation accuracy: 0.571000
# lr 5.000000e-01 reg 5.000000e-07 hidden units 100 training accuracy: 0.604429 validation accuracy: 0.568000
# best validation accuracy: 0.571000
# lr 5.000000e-01 reg 1.000000e-06 hidden units 100 training accuracy: 0.606857 validation accuracy: 0.566000
# best validation accuracy: 0.571000
# lr 5.000000e-01 reg 5.000000e-06 hidden units 100 training accuracy: 0.609735 validation accuracy: 0.547000
# best validation accuracy: 0.571000
# lr 5.000000e-01 reg 1.000000e-05 hidden units 100 training accuracy: 0.607347 validation accuracy: 0.565000
# best validation accuracy: 0.571000
# lr 5.000000e-01 reg 5.000000e-05 hidden units 100 training accuracy: 0.603571 validation accuracy: 0.566000
# best validation accuracy: 0.571000
# lr 5.000000e-01 reg 1.000000e-04 hidden units 100 training accuracy: 0.599265 validation accuracy: 0.559000
# best validation accuracy: 0.571000
# lr 5.000000e-01 reg 5.000000e-04 hidden units 100 training accuracy: 0.591367 validation accuracy: 0.543000
# best validation accuracy: 0.571000
# lr 1.000000e-01 reg 1.000000e-07 hidden units 150 training accuracy: 0.520694 validation accuracy: 0.514000
# best validation accuracy: 0.571000
# lr 1.000000e-01 reg 5.000000e-07 hidden units 150 training accuracy: 0.519592 validation accuracy: 0.503000
# best validation accuracy: 0.571000
# lr 1.000000e-01 reg 1.000000e-06 hidden units 150 training accuracy: 0.517367 validation accuracy: 0.506000
# best validation accuracy: 0.571000
# lr 1.000000e-01 reg 5.000000e-06 hidden units 150 training accuracy: 0.518122 validation accuracy: 0.504000
# best validation accuracy: 0.571000
# lr 1.000000e-01 reg 1.000000e-05 hidden units 150 training accuracy: 0.519000 validation accuracy: 0.515000
# best validation accuracy: 0.571000
# lr 1.000000e-01 reg 5.000000e-05 hidden units 150 training accuracy: 0.520469 validation accuracy: 0.519000
# best validation accuracy: 0.571000
# lr 1.000000e-01 reg 1.000000e-04 hidden units 150 training accuracy: 0.517653 validation accuracy: 0.519000
# best validation accuracy: 0.571000
# lr 1.000000e-01 reg 5.000000e-04 hidden units 150 training accuracy: 0.518918 validation accuracy: 0.514000
# best validation accuracy: 0.571000
# lr 2.000000e-01 reg 1.000000e-07 hidden units 150 training accuracy: 0.557347 validation accuracy: 0.535000
# best validation accuracy: 0.571000
# lr 2.000000e-01 reg 5.000000e-07 hidden units 150 training accuracy: 0.554531 validation accuracy: 0.515000
# best validation accuracy: 0.571000
# lr 2.000000e-01 reg 1.000000e-06 hidden units 150 training accuracy: 0.557061 validation accuracy: 0.543000
# best validation accuracy: 0.571000
# lr 2.000000e-01 reg 5.000000e-06 hidden units 150 training accuracy: 0.553878 validation accuracy: 0.537000
# best validation accuracy: 0.571000
# lr 2.000000e-01 reg 1.000000e-05 hidden units 150 training accuracy: 0.553510 validation accuracy: 0.533000
# best validation accuracy: 0.571000
# lr 2.000000e-01 reg 5.000000e-05 hidden units 150 training accuracy: 0.558347 validation accuracy: 0.543000
# best validation accuracy: 0.571000
# lr 2.000000e-01 reg 1.000000e-04 hidden units 150 training accuracy: 0.557000 validation accuracy: 0.541000
# best validation accuracy: 0.571000
# lr 2.000000e-01 reg 5.000000e-04 hidden units 150 training accuracy: 0.553306 validation accuracy: 0.537000
# best validation accuracy: 0.571000
# lr 3.000000e-01 reg 1.000000e-07 hidden units 150 training accuracy: 0.582245 validation accuracy: 0.572000
# best validation accuracy: 0.572000
# lr 3.000000e-01 reg 5.000000e-07 hidden units 150 training accuracy: 0.585837 validation accuracy: 0.570000
# best validation accuracy: 0.572000
# lr 3.000000e-01 reg 1.000000e-06 hidden units 150 training accuracy: 0.582857 validation accuracy: 0.553000
# best validation accuracy: 0.572000
# lr 3.000000e-01 reg 5.000000e-06 hidden units 150 training accuracy: 0.586122 validation accuracy: 0.558000
# best validation accuracy: 0.572000
# lr 3.000000e-01 reg 1.000000e-05 hidden units 150 training accuracy: 0.579939 validation accuracy: 0.543000
# best validation accuracy: 0.572000
# lr 3.000000e-01 reg 5.000000e-05 hidden units 150 training accuracy: 0.587367 validation accuracy: 0.559000
# best validation accuracy: 0.572000
# lr 3.000000e-01 reg 1.000000e-04 hidden units 150 training accuracy: 0.584612 validation accuracy: 0.557000
# best validation accuracy: 0.572000
# lr 3.000000e-01 reg 5.000000e-04 hidden units 150 training accuracy: 0.576694 validation accuracy: 0.526000
# best validation accuracy: 0.572000
# lr 4.000000e-01 reg 1.000000e-07 hidden units 150 training accuracy: 0.596612 validation accuracy: 0.550000
# best validation accuracy: 0.572000
# lr 4.000000e-01 reg 5.000000e-07 hidden units 150 training accuracy: 0.603898 validation accuracy: 0.558000
# best validation accuracy: 0.572000
# lr 4.000000e-01 reg 1.000000e-06 hidden units 150 training accuracy: 0.598714 validation accuracy: 0.564000
# best validation accuracy: 0.572000
# lr 4.000000e-01 reg 5.000000e-06 hidden units 150 training accuracy: 0.602082 validation accuracy: 0.549000
# best validation accuracy: 0.572000
# lr 4.000000e-01 reg 1.000000e-05 hidden units 150 training accuracy: 0.603694 validation accuracy: 0.576000
# best validation accuracy: 0.576000
# lr 4.000000e-01 reg 5.000000e-05 hidden units 150 training accuracy: 0.605204 validation accuracy: 0.570000
# best validation accuracy: 0.576000
# lr 4.000000e-01 reg 1.000000e-04 hidden units 150 training accuracy: 0.596367 validation accuracy: 0.543000
# best validation accuracy: 0.576000
# lr 4.000000e-01 reg 5.000000e-04 hidden units 150 training accuracy: 0.594633 validation accuracy: 0.570000
# best validation accuracy: 0.576000
# lr 5.000000e-01 reg 1.000000e-07 hidden units 150 training accuracy: 0.611204 validation accuracy: 0.557000
# best validation accuracy: 0.576000
# lr 5.000000e-01 reg 5.000000e-07 hidden units 150 training accuracy: 0.611898 validation accuracy: 0.543000
# best validation accuracy: 0.576000
# lr 5.000000e-01 reg 1.000000e-06 hidden units 150 training accuracy: 0.613633 validation accuracy: 0.554000
# best validation accuracy: 0.576000
# lr 5.000000e-01 reg 5.000000e-06 hidden units 150 training accuracy: 0.616041 validation accuracy: 0.575000
# best validation accuracy: 0.576000
# lr 5.000000e-01 reg 1.000000e-05 hidden units 150 training accuracy: 0.607388 validation accuracy: 0.555000
# best validation accuracy: 0.576000
# lr 5.000000e-01 reg 5.000000e-05 hidden units 150 training accuracy: 0.610571 validation accuracy: 0.561000
# best validation accuracy: 0.576000
# lr 5.000000e-01 reg 1.000000e-04 hidden units 150 training accuracy: 0.617571 validation accuracy: 0.571000
# best validation accuracy: 0.576000
# lr 5.000000e-01 reg 5.000000e-04 hidden units 150 training accuracy: 0.599816 validation accuracy: 0.564000
# best validation accuracy: 0.576000
# lr 1.000000e-01 reg 1.000000e-07 hidden units 200 training accuracy: 0.520184 validation accuracy: 0.513000
# best validation accuracy: 0.576000
# lr 1.000000e-01 reg 5.000000e-07 hidden units 200 training accuracy: 0.523918 validation accuracy: 0.514000
# best validation accuracy: 0.576000
# lr 1.000000e-01 reg 1.000000e-06 hidden units 200 training accuracy: 0.519633 validation accuracy: 0.503000
# best validation accuracy: 0.576000
# lr 1.000000e-01 reg 5.000000e-06 hidden units 200 training accuracy: 0.520959 validation accuracy: 0.521000
# best validation accuracy: 0.576000
# lr 1.000000e-01 reg 1.000000e-05 hidden units 200 training accuracy: 0.522224 validation accuracy: 0.518000
# best validation accuracy: 0.576000
# lr 1.000000e-01 reg 5.000000e-05 hidden units 200 training accuracy: 0.521184 validation accuracy: 0.509000
# best validation accuracy: 0.576000
# lr 1.000000e-01 reg 1.000000e-04 hidden units 200 training accuracy: 0.521980 validation accuracy: 0.505000
# best validation accuracy: 0.576000
# lr 1.000000e-01 reg 5.000000e-04 hidden units 200 training accuracy: 0.519163 validation accuracy: 0.506000
# best validation accuracy: 0.576000
# lr 2.000000e-01 reg 1.000000e-07 hidden units 200 training accuracy: 0.557735 validation accuracy: 0.536000
# best validation accuracy: 0.576000
# lr 2.000000e-01 reg 5.000000e-07 hidden units 200 training accuracy: 0.559959 validation accuracy: 0.545000
# best validation accuracy: 0.576000
# lr 2.000000e-01 reg 1.000000e-06 hidden units 200 training accuracy: 0.557612 validation accuracy: 0.535000
# best validation accuracy: 0.576000
# lr 2.000000e-01 reg 5.000000e-06 hidden units 200 training accuracy: 0.559143 validation accuracy: 0.537000
# best validation accuracy: 0.576000
# lr 2.000000e-01 reg 1.000000e-05 hidden units 200 training accuracy: 0.555469 validation accuracy: 0.535000
# best validation accuracy: 0.576000
# lr 2.000000e-01 reg 5.000000e-05 hidden units 200 training accuracy: 0.558388 validation accuracy: 0.547000
# best validation accuracy: 0.576000
# lr 2.000000e-01 reg 1.000000e-04 hidden units 200 training accuracy: 0.560041 validation accuracy: 0.534000
# best validation accuracy: 0.576000
# lr 2.000000e-01 reg 5.000000e-04 hidden units 200 training accuracy: 0.557245 validation accuracy: 0.542000
# best validation accuracy: 0.576000
# lr 3.000000e-01 reg 1.000000e-07 hidden units 200 training accuracy: 0.592224 validation accuracy: 0.565000
# best validation accuracy: 0.576000
# lr 3.000000e-01 reg 5.000000e-07 hidden units 200 training accuracy: 0.583204 validation accuracy: 0.549000
# best validation accuracy: 0.576000
# lr 3.000000e-01 reg 1.000000e-06 hidden units 200 training accuracy: 0.591102 validation accuracy: 0.560000
# best validation accuracy: 0.576000
# lr 3.000000e-01 reg 5.000000e-06 hidden units 200 training accuracy: 0.584592 validation accuracy: 0.558000
# best validation accuracy: 0.576000
# lr 3.000000e-01 reg 1.000000e-05 hidden units 200 training accuracy: 0.587612 validation accuracy: 0.561000
# best validation accuracy: 0.576000
# lr 3.000000e-01 reg 5.000000e-05 hidden units 200 training accuracy: 0.586694 validation accuracy: 0.563000
# best validation accuracy: 0.576000
# lr 3.000000e-01 reg 1.000000e-04 hidden units 200 training accuracy: 0.580102 validation accuracy: 0.555000
# best validation accuracy: 0.576000
# lr 3.000000e-01 reg 5.000000e-04 hidden units 200 training accuracy: 0.585633 validation accuracy: 0.548000
# best validation accuracy: 0.576000
# lr 4.000000e-01 reg 1.000000e-07 hidden units 200 training accuracy: 0.613694 validation accuracy: 0.570000
# best validation accuracy: 0.576000
# lr 4.000000e-01 reg 5.000000e-07 hidden units 200 training accuracy: 0.603531 validation accuracy: 0.567000
# best validation accuracy: 0.576000
# lr 4.000000e-01 reg 1.000000e-06 hidden units 200 training accuracy: 0.612245 validation accuracy: 0.574000
# best validation accuracy: 0.576000
# lr 4.000000e-01 reg 5.000000e-06 hidden units 200 training accuracy: 0.610429 validation accuracy: 0.564000
# best validation accuracy: 0.576000
# lr 4.000000e-01 reg 1.000000e-05 hidden units 200 training accuracy: 0.610918 validation accuracy: 0.545000
# best validation accuracy: 0.576000
# lr 4.000000e-01 reg 5.000000e-05 hidden units 200 training accuracy: 0.599857 validation accuracy: 0.563000
# best validation accuracy: 0.576000
# lr 4.000000e-01 reg 1.000000e-04 hidden units 200 training accuracy: 0.605000 validation accuracy: 0.584000
# best validation accuracy: 0.584000
# lr 4.000000e-01 reg 5.000000e-04 hidden units 200 training accuracy: 0.603939 validation accuracy: 0.559000
# best validation accuracy: 0.584000
# lr 5.000000e-01 reg 1.000000e-07 hidden units 200 training accuracy: 0.620694 validation accuracy: 0.582000
# best validation accuracy: 0.584000
# lr 5.000000e-01 reg 5.000000e-07 hidden units 200 training accuracy: 0.617143 validation accuracy: 0.565000
# best validation accuracy: 0.584000
# lr 5.000000e-01 reg 1.000000e-06 hidden units 200 training accuracy: 0.626102 validation accuracy: 0.582000
# best validation accuracy: 0.584000
# lr 5.000000e-01 reg 5.000000e-06 hidden units 200 training accuracy: 0.615980 validation accuracy: 0.575000
# best validation accuracy: 0.584000
# lr 5.000000e-01 reg 1.000000e-05 hidden units 200 training accuracy: 0.622612 validation accuracy: 0.560000
# best validation accuracy: 0.584000
# lr 5.000000e-01 reg 5.000000e-05 hidden units 200 training accuracy: 0.623102 validation accuracy: 0.570000
# best validation accuracy: 0.584000
# lr 5.000000e-01 reg 1.000000e-04 hidden units 200 training accuracy: 0.623551 validation accuracy: 0.592000
# best validation accuracy: 0.592000
# lr 5.000000e-01 reg 5.000000e-04 hidden units 200 training accuracy: 0.611796 validation accuracy: 0.562000
# best validation accuracy: 0.592000
# lr 1.000000e-01 reg 1.000000e-07 hidden units 300 training accuracy: 0.520184 validation accuracy: 0.505000
# best validation accuracy: 0.592000
# lr 1.000000e-01 reg 5.000000e-07 hidden units 300 training accuracy: 0.518020 validation accuracy: 0.506000
# best validation accuracy: 0.592000
# lr 1.000000e-01 reg 1.000000e-06 hidden units 300 training accuracy: 0.521776 validation accuracy: 0.516000
# best validation accuracy: 0.592000
# lr 1.000000e-01 reg 5.000000e-06 hidden units 300 training accuracy: 0.522490 validation accuracy: 0.500000
# best validation accuracy: 0.592000
# lr 1.000000e-01 reg 1.000000e-05 hidden units 300 training accuracy: 0.522204 validation accuracy: 0.504000
# best validation accuracy: 0.592000
# lr 1.000000e-01 reg 5.000000e-05 hidden units 300 training accuracy: 0.521143 validation accuracy: 0.503000
# best validation accuracy: 0.592000
# lr 1.000000e-01 reg 1.000000e-04 hidden units 300 training accuracy: 0.522837 validation accuracy: 0.503000
# best validation accuracy: 0.592000
# lr 1.000000e-01 reg 5.000000e-04 hidden units 300 training accuracy: 0.522469 validation accuracy: 0.507000
# best validation accuracy: 0.592000
# lr 2.000000e-01 reg 1.000000e-07 hidden units 300 training accuracy: 0.561469 validation accuracy: 0.545000
# best validation accuracy: 0.592000
# lr 2.000000e-01 reg 5.000000e-07 hidden units 300 training accuracy: 0.559408 validation accuracy: 0.544000
# best validation accuracy: 0.592000
# lr 2.000000e-01 reg 1.000000e-06 hidden units 300 training accuracy: 0.560959 validation accuracy: 0.543000
# best validation accuracy: 0.592000
# lr 2.000000e-01 reg 5.000000e-06 hidden units 300 training accuracy: 0.560041 validation accuracy: 0.534000
# best validation accuracy: 0.592000
# lr 2.000000e-01 reg 1.000000e-05 hidden units 300 training accuracy: 0.558367 validation accuracy: 0.532000
# best validation accuracy: 0.592000
# lr 2.000000e-01 reg 5.000000e-05 hidden units 300 training accuracy: 0.560673 validation accuracy: 0.537000
# best validation accuracy: 0.592000
# lr 2.000000e-01 reg 1.000000e-04 hidden units 300 training accuracy: 0.561061 validation accuracy: 0.535000
# best validation accuracy: 0.592000
# lr 2.000000e-01 reg 5.000000e-04 hidden units 300 training accuracy: 0.556286 validation accuracy: 0.526000
# best validation accuracy: 0.592000
# lr 3.000000e-01 reg 1.000000e-07 hidden units 300 training accuracy: 0.596449 validation accuracy: 0.574000
# best validation accuracy: 0.592000
# lr 3.000000e-01 reg 5.000000e-07 hidden units 300 training accuracy: 0.590163 validation accuracy: 0.559000
# best validation accuracy: 0.592000
# lr 3.000000e-01 reg 1.000000e-06 hidden units 300 training accuracy: 0.593878 validation accuracy: 0.557000
# best validation accuracy: 0.592000
# lr 3.000000e-01 reg 5.000000e-06 hidden units 300 training accuracy: 0.596510 validation accuracy: 0.563000
# best validation accuracy: 0.592000
# lr 3.000000e-01 reg 1.000000e-05 hidden units 300 training accuracy: 0.586122 validation accuracy: 0.560000
# best validation accuracy: 0.592000
# lr 3.000000e-01 reg 5.000000e-05 hidden units 300 training accuracy: 0.597653 validation accuracy: 0.579000
# best validation accuracy: 0.592000
# lr 3.000000e-01 reg 1.000000e-04 hidden units 300 training accuracy: 0.592918 validation accuracy: 0.563000
# best validation accuracy: 0.592000
# lr 3.000000e-01 reg 5.000000e-04 hidden units 300 training accuracy: 0.588653 validation accuracy: 0.549000
# best validation accuracy: 0.592000
# lr 4.000000e-01 reg 1.000000e-07 hidden units 300 training accuracy: 0.615469 validation accuracy: 0.594000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 5.000000e-07 hidden units 300 training accuracy: 0.613653 validation accuracy: 0.561000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 1.000000e-06 hidden units 300 training accuracy: 0.614327 validation accuracy: 0.572000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 5.000000e-06 hidden units 300 training accuracy: 0.612184 validation accuracy: 0.579000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 1.000000e-05 hidden units 300 training accuracy: 0.615510 validation accuracy: 0.567000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 5.000000e-05 hidden units 300 training accuracy: 0.615388 validation accuracy: 0.574000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 1.000000e-04 hidden units 300 training accuracy: 0.609735 validation accuracy: 0.550000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 5.000000e-04 hidden units 300 training accuracy: 0.595735 validation accuracy: 0.570000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 1.000000e-07 hidden units 300 training accuracy: 0.625796 validation accuracy: 0.582000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-07 hidden units 300 training accuracy: 0.625306 validation accuracy: 0.571000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 1.000000e-06 hidden units 300 training accuracy: 0.628388 validation accuracy: 0.577000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-06 hidden units 300 training accuracy: 0.626694 validation accuracy: 0.569000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 1.000000e-05 hidden units 300 training accuracy: 0.628592 validation accuracy: 0.567000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-05 hidden units 300 training accuracy: 0.623367 validation accuracy: 0.564000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 1.000000e-04 hidden units 300 training accuracy: 0.628163 validation accuracy: 0.558000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-04 hidden units 300 training accuracy: 0.620490 validation accuracy: 0.586000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 1.000000e-07 hidden units 400 training accuracy: 0.522490 validation accuracy: 0.507000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 5.000000e-07 hidden units 400 training accuracy: 0.523000 validation accuracy: 0.506000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 1.000000e-06 hidden units 400 training accuracy: 0.524531 validation accuracy: 0.513000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 5.000000e-06 hidden units 400 training accuracy: 0.523184 validation accuracy: 0.512000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 1.000000e-05 hidden units 400 training accuracy: 0.523184 validation accuracy: 0.523000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 5.000000e-05 hidden units 400 training accuracy: 0.522429 validation accuracy: 0.511000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 1.000000e-04 hidden units 400 training accuracy: 0.521857 validation accuracy: 0.505000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 5.000000e-04 hidden units 400 training accuracy: 0.524143 validation accuracy: 0.513000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 1.000000e-07 hidden units 400 training accuracy: 0.563143 validation accuracy: 0.540000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 5.000000e-07 hidden units 400 training accuracy: 0.560653 validation accuracy: 0.535000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 1.000000e-06 hidden units 400 training accuracy: 0.561653 validation accuracy: 0.543000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 5.000000e-06 hidden units 400 training accuracy: 0.562939 validation accuracy: 0.531000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 1.000000e-05 hidden units 400 training accuracy: 0.559347 validation accuracy: 0.528000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 5.000000e-05 hidden units 400 training accuracy: 0.562673 validation accuracy: 0.544000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 1.000000e-04 hidden units 400 training accuracy: 0.560041 validation accuracy: 0.544000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 5.000000e-04 hidden units 400 training accuracy: 0.559224 validation accuracy: 0.540000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 1.000000e-07 hidden units 400 training accuracy: 0.596388 validation accuracy: 0.572000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 5.000000e-07 hidden units 400 training accuracy: 0.594061 validation accuracy: 0.570000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 1.000000e-06 hidden units 400 training accuracy: 0.595163 validation accuracy: 0.562000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 5.000000e-06 hidden units 400 training accuracy: 0.595429 validation accuracy: 0.565000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 1.000000e-05 hidden units 400 training accuracy: 0.590694 validation accuracy: 0.560000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 5.000000e-05 hidden units 400 training accuracy: 0.592367 validation accuracy: 0.544000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 1.000000e-04 hidden units 400 training accuracy: 0.594959 validation accuracy: 0.561000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 5.000000e-04 hidden units 400 training accuracy: 0.587163 validation accuracy: 0.560000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 1.000000e-07 hidden units 400 training accuracy: 0.618224 validation accuracy: 0.584000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 5.000000e-07 hidden units 400 training accuracy: 0.616633 validation accuracy: 0.569000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 1.000000e-06 hidden units 400 training accuracy: 0.619429 validation accuracy: 0.573000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 5.000000e-06 hidden units 400 training accuracy: 0.616327 validation accuracy: 0.591000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 1.000000e-05 hidden units 400 training accuracy: 0.616694 validation accuracy: 0.579000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 5.000000e-05 hidden units 400 training accuracy: 0.613184 validation accuracy: 0.578000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 1.000000e-04 hidden units 400 training accuracy: 0.615163 validation accuracy: 0.576000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 5.000000e-04 hidden units 400 training accuracy: 0.600571 validation accuracy: 0.559000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 1.000000e-07 hidden units 400 training accuracy: 0.633204 validation accuracy: 0.585000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-07 hidden units 400 training accuracy: 0.635020 validation accuracy: 0.577000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 1.000000e-06 hidden units 400 training accuracy: 0.629429 validation accuracy: 0.563000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-06 hidden units 400 training accuracy: 0.638388 validation accuracy: 0.585000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 1.000000e-05 hidden units 400 training accuracy: 0.640918 validation accuracy: 0.590000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-05 hidden units 400 training accuracy: 0.634694 validation accuracy: 0.559000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 1.000000e-04 hidden units 400 training accuracy: 0.627061 validation accuracy: 0.584000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-04 hidden units 400 training accuracy: 0.617367 validation accuracy: 0.579000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 1.000000e-07 hidden units 500 training accuracy: 0.524673 validation accuracy: 0.525000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 5.000000e-07 hidden units 500 training accuracy: 0.522347 validation accuracy: 0.516000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 1.000000e-06 hidden units 500 training accuracy: 0.524245 validation accuracy: 0.509000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 5.000000e-06 hidden units 500 training accuracy: 0.525245 validation accuracy: 0.517000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 1.000000e-05 hidden units 500 training accuracy: 0.524551 validation accuracy: 0.503000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 5.000000e-05 hidden units 500 training accuracy: 0.523102 validation accuracy: 0.516000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 1.000000e-04 hidden units 500 training accuracy: 0.524980 validation accuracy: 0.515000
# best validation accuracy: 0.594000
# lr 1.000000e-01 reg 5.000000e-04 hidden units 500 training accuracy: 0.522347 validation accuracy: 0.513000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 1.000000e-07 hidden units 500 training accuracy: 0.563020 validation accuracy: 0.541000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 5.000000e-07 hidden units 500 training accuracy: 0.563224 validation accuracy: 0.541000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 1.000000e-06 hidden units 500 training accuracy: 0.560878 validation accuracy: 0.536000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 5.000000e-06 hidden units 500 training accuracy: 0.560571 validation accuracy: 0.546000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 1.000000e-05 hidden units 500 training accuracy: 0.563041 validation accuracy: 0.536000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 5.000000e-05 hidden units 500 training accuracy: 0.562490 validation accuracy: 0.542000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 1.000000e-04 hidden units 500 training accuracy: 0.558612 validation accuracy: 0.536000
# best validation accuracy: 0.594000
# lr 2.000000e-01 reg 5.000000e-04 hidden units 500 training accuracy: 0.561449 validation accuracy: 0.548000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 1.000000e-07 hidden units 500 training accuracy: 0.597020 validation accuracy: 0.562000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 5.000000e-07 hidden units 500 training accuracy: 0.596245 validation accuracy: 0.550000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 1.000000e-06 hidden units 500 training accuracy: 0.593224 validation accuracy: 0.564000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 5.000000e-06 hidden units 500 training accuracy: 0.592980 validation accuracy: 0.567000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 1.000000e-05 hidden units 500 training accuracy: 0.597163 validation accuracy: 0.564000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 5.000000e-05 hidden units 500 training accuracy: 0.595306 validation accuracy: 0.559000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 1.000000e-04 hidden units 500 training accuracy: 0.595122 validation accuracy: 0.576000
# best validation accuracy: 0.594000
# lr 3.000000e-01 reg 5.000000e-04 hidden units 500 training accuracy: 0.590837 validation accuracy: 0.558000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 1.000000e-07 hidden units 500 training accuracy: 0.613714 validation accuracy: 0.553000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 5.000000e-07 hidden units 500 training accuracy: 0.614000 validation accuracy: 0.538000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 1.000000e-06 hidden units 500 training accuracy: 0.621082 validation accuracy: 0.582000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 5.000000e-06 hidden units 500 training accuracy: 0.625020 validation accuracy: 0.587000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 1.000000e-05 hidden units 500 training accuracy: 0.620551 validation accuracy: 0.580000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 5.000000e-05 hidden units 500 training accuracy: 0.619429 validation accuracy: 0.576000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 1.000000e-04 hidden units 500 training accuracy: 0.620735 validation accuracy: 0.581000
# best validation accuracy: 0.594000
# lr 4.000000e-01 reg 5.000000e-04 hidden units 500 training accuracy: 0.605612 validation accuracy: 0.567000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 1.000000e-07 hidden units 500 training accuracy: 0.640041 validation accuracy: 0.572000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-07 hidden units 500 training accuracy: 0.638224 validation accuracy: 0.566000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 1.000000e-06 hidden units 500 training accuracy: 0.634592 validation accuracy: 0.566000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-06 hidden units 500 training accuracy: 0.634184 validation accuracy: 0.572000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 1.000000e-05 hidden units 500 training accuracy: 0.636306 validation accuracy: 0.570000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-05 hidden units 500 training accuracy: 0.629367 validation accuracy: 0.574000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 1.000000e-04 hidden units 500 training accuracy: 0.635327 validation accuracy: 0.568000
# best validation accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-04 hidden units 500 training accuracy: 0.625388 validation accuracy: 0.576000
# best validation accuracy: 0.594000

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.57
